# %% [markdown]
# # Webscraping Properties for sale at ST properties

# %%
import requests
from bs4 import BeautifulSoup

# %%
pages = []

for i in range(1, 12):
    if i == 1:
        url = 'https://www.stproperty.sg/property-for-sale'
        pages.append(url)
    else:
        url = 'https://www.stproperty.sg/property-for-sale/page' + str(i) + '#searchresults'
        pages.append(url)

# %%
pages[:5]
# Out:
# ['https://www.stproperty.sg/property-for-sale',
#  'https://www.stproperty.sg/property-for-sale/page2#searchresults',
#  'https://www.stproperty.sg/property-for-sale/page3#searchresults',
#  'https://www.stproperty.sg/property-for-sale/page4#searchresults',
#  'https://www.stproperty.sg/property-for-sale/page5#searchresults']

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# <h5> <a href="/landed-for-sale/semi-detached-house-for-sale/seletar-hills-estate/32138081"><strong>Seletar Hills Estate - For Sale</strong></a>
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script src="https://www.stproperty.sg/js/jquery-1.8.2.min.js">
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Find property for sale in Singapore property listings, real estates for sale in Singapore Property Listings.Browse condo for sale, hdb for sale, commercial and landed property for sale in Singapore page 11 at STProperty with 10 Results Per Page." name="description"/>
#   <meta content="Property for Sale,Singapore Property" name="keywords"/>
#   <link href="/assets/87d84fff/jui/css/base/jquery-ui.css" rel="stylesheet" type="text/css"/>
#   <link href="/assets/674d5472/css/colorbox.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/01.stproperty_site.css?277" rel="stylesheet" type="text/css"/>
#   <link href="/css/chosen.css?277" rel="stylesheet" type="text/css"/>
#   <link href="/css/bootstrap.min.css?277" rel="stylesheet" type="text/css"/>
# ...

# %%
# We are going to loop over all eleven pages and append each entry to a new list

l = []

for i in pages:
    page = requests.get(i)
    soup = BeautifulSoup(page.text, 'html.parser')
#     x = soup.find_all(class_= 'col-xs-12')
    x = soup.h5
#     for div in x:
#         print(div.find('a')['href'])
#     for i in x:
#         l.append(i)

# %%
 for div in soup.find_all('div', class_= 'col-xs-12'):
        for h5 in div.find_all('h5'):
            a = li.find('a')
            print(a['href'], a.get_text())

# %%
# for div in soup.findAll('div', attrs={'a'}):
#     print(div.find('href'))
type(l)
# Out:
# list

# %%
l[:1].split('<')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-2606f5c74cef> in <module>
# ----> 1 l[:1].split('<')
#
# AttributeError: 'list' object has no attribute 'split'

# %%
for line in l:
    Type = line.split("<")
    x = Type[1]
    y = Type[2]
    print(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-972db232a83a> in <module>
#       1 for line in l:
# ----> 2     Type = line.split("<")
#       3     x = Type[1]
#       4     y = Type[2]
#       5     print(x,y)
#
# TypeError: 'NoneType' object is not callable

# %%
# Let's see if the results look okay

l[:1]
# Out:
# [<div class="col-xs-12">
#  <ul class="nav navbar-nav pull-right nav-member-links">
#  <li><a href="/user/userfavourites/index" onclick="_gaq.push(['_trackEvent', 'My_STProperty_Toolbox', 'Click', '3'])">My Favourites (<span id="myfavs">0</span>)</a></li>
#  <li><a href="https://www.stproperty.sg/agent/agentmembership/list">Property Agent</a></li>
#  <li>
#  <div class="nav navbar-nav pull-right nav-member-links dropdown"> <a class="dropdown-toggle" data-toggle="dropdown" href="#" style="text-decoration: none">My Shortcuts<b class="caret"></b></a>
#  <ul class="dropdown-menu">
#  <li>
#  <a href="/p/user/userprofile/index" onclick="_gaq.push(['_trackEvent', 'My_STProperty_Toolbox', 'Click', '1'])"><span class="icon-myprofile"></span>My Profile</a> </li>
#  <li>
#  <a href="/p/user/usercompareads/index" onclick="_gaq.push(['_trackEvent', 'My_STProperty_Toolbox', 'Click', '2'])"><span class="icon-mycomparisons"></span>My Comparisons</a> </li>
#  <li>
# ...

# %%
l[1:2]
# Out:
# [<div class="col-xs-12">
#  <form action="/search/searchlistings/seosearch" class="navbar-form navbar-search" method="GET"> <div class="input-group" style="position:absolute;right:247px;"><span class="tool-tip"><a class="tool-tip pull-left" data-original-title="Search by entering keywords for most relevant results available on the website" data-toggle="tooltip" href="#">?</a></span>
#  <input class="form-control" id="fedkeysearch" name="keyword" placeholder="Search entire site" type="text" value=""/><input id="federated" name="federated" type="hidden" value="1"/> <input id="fedautosuggesttype" name="autosuggesttype" type="hidden" value=""/><input id="fedautosuggestid" name="autosuggestid" type="hidden" value=""/><input id="fedautosuggestarea" name="autosuggestarea" type="hidden" value=""/><input id="fedautocomplete" name="fedautocomplete" type="hidden" value=""/> <div class="autocomplete-container">
#  <div class="autocomplete-header-search">
#  <div id="aplist1">
#  </div>
# ...
